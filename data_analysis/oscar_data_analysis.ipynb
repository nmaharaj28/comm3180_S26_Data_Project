# %% [markdown]
# # TITLE
#
# * description
# * documentation

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
oscars = pd.read_csv("../data/oscars_final.csv")

# %%
oscars.groupby(['race_ethnicity', 'award']).size().unstack().plot(kind='bar', stacked=True)
plt.show()

# %%
categories = [
    'Best Actor',
    'Best Actress',
    'Best Director',
    'Best Supporting Actor',
    'Best Supporting Actress'
]

for category in categories:
    subset = oscars[oscars['award'] == category]
    
    plot_data = (
        subset
        .groupby(['race_ethnicity'])
        .size()
        .sort_values(ascending=False)
    )
    
    plot_data.plot(kind='bar')
    plt.title(f'{category} by Race/Ethnicity')
    plt.xlabel('Race/Ethnicity')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
for category in categories:
    subset = oscars[oscars['award'] == category]
    
    trend = (
        subset
        .groupby(['year_of_award', 'race_ethnicity'])
        .size()
        .unstack(fill_value=0)
    )
    
    trend.plot(kind='area', stacked=True, figsize=(10, 5))
    plt.title(f'{category} by Race/Ethnicity Over Time')
    plt.xlabel('Year')
    plt.ylabel('Count')
    plt.show()

# %%
# NEXT STEP: Direct comparison with census-reported demographic proportions?
# 21st century, classify the nominees as well, do full analysis -> compare with oscarssowhite before and after; top 100 movies in a year?
